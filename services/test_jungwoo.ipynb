# %%
from dotenv import load_dotenv
import os
from langchain import hub
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain_community.vectorstores import Chroma, FAISS
from langchain_core.output_parsers import StrOutputParser
from langchain_core.runnables import RunnablePassthrough
from langchain_openai import ChatOpenAI, OpenAIEmbeddings
from langchain_teddynote.document_loaders import HWPLoader

load_dotenv()
# Out:
# True

# %%
loader = HWPLoader("C:/Users/wjddn/Documents/taejung/volume/test.hwp")
docs = loader.load()

# %%
print(repr(docs[0].page_content))
# Out:
# '주소안내연세대학교 미래캠퍼스의 주소는 강원특별자치도 원주시 연세대길 1 (우편번호: 26493)이며, 영문 주소는 1 Yonseidae-gil, Wonju, Gangwon State, 26493, Republic of Korea입니다.대표 전화번호는 1599-1885이며, 대표 이메일 주소는 ╨wadmin@yonsei.ac.krh입니다.교통안내자가용 이용:영동고속도로를 이용하여 중앙고속도로로 진입(만종분기점) 후, 남원주나들목(남원주 I.C.)을 통과하여 충주 방향으로 7km직진하면 도착할 수 있습니다.철도 이용:중앙선: 서울(청량리역)에서 출발하여 원주 → 안동 → 부산방향으로 이동 가능합니다.경강선: 서울(서울역 또는 청량리역)에서 출발하여 원주 → 강릉방면으로 이동할 수 있습니다.항공 이용:원주에서 제주도로 항공편 이용이 가능합니다.시내버스 이용:시외·고속버스터미널(정류장 번호 60036)에서 30번, 34번, 34-1번 버스를 탑승하면 캠퍼스 내까지 진입할 수 있습니다.원주역(흥업방면, 정류장 번호 68585)에서 30번, 34-1번 버스를 탑승하면 교내까지 이동할 수 있습니다.연세대학교 미래캠퍼스 2024 전화번호부 (부서별 연락처)전화번호는 지역번호 033-760이후의 내선번호 4자리로 표시됩니다.교무부: 033-760-2158, 033-760-2589, 033-760-2714원주기획처: 033-760-2112, 033-760-2117, 033-760-5500예비군연대: 033-760-2542, 033-760-2584대학교회: 033-760-2871연세교육센터: 033-760-5133연세스포츠센터: 033-760-5135연세예술원: 033-760-5127소프트웨어디지털헬스케어융합대학: 033-760-2420글로벌창의융합대학: 033-760-2302, 033-760-2303, 033-760-2304, 033-760-2745, 033-760-2985의과대학 교학팀: 033-760-3372치과대학: 033-760-2850약학대학: 033-760-28
# ...

# %%
from langchain_core.documents import Document

# 텍스트 파일 경로
txt_path = "C:/Users/wjddn/Documents/taejung/volume/test.txt"  # 실제 파일 경로로 수정

# 파일 열기
with open(txt_path, "r", encoding="utf-8") as f:
    text = f.read()

# 정확히 \n\n 기준으로 자르기
chunks = text.split("\n\n")

# 빈 줄 제거 + Document로 감싸기
docs = [Document(page_content=chunk.strip()) for chunk in chunks if chunk.strip()]

# 결과 출력
for i, doc in enumerate(docs, 1):
    print(f"[{i}]")
    print(doc.page_content)
    print("-" * 40)
# Out:
# [1]
# ﻿주소안내
# 연세대학교 미래캠퍼스의 주소는 강원특별자치도 원주시 연세대길 1 (우편번호: 26493)이며, 영문 주소는 1 Yonseidae-gil, Wonju, Gangwon State, 26493, Republic of Korea입니다.
# 대표 전화번호는 1599-1885이며, 대표 이메일 주소는 wadmin@yonsei.ac.kr입니다.
# ----------------------------------------
# [2]
# 교통안내
# • 자가용 이용:영동고속도로를 이용하여 중앙고속도로로 진입(만종분기점) 후, 남원주나들목(남원주 I.C.)을 통과하여 충주 방향으로 7km직진하면 도착할 수 있습니다.
# ----------------------------------------
# [3]
# • 철도 이용:
# • 중앙선: 서울(청량리역)에서 출발하여 원주 → 안동 → 부산방향으로 이동 가능합니다.
# • 경강선: 서울(서울역 또는 청량리역)에서 출발하여 원주 → 강릉방면으로 이동할 수 있습니다.
# 항공 이용:원주에서 제주도로 항공편 이용이 가능합니다.
# ----------------------------------------
# [4]
# 시내버스 이용:
# • 시외·고속버스터미널(정류장 번호 60036)에서 30번, 34번, 34-1번 버스를 탑승하면 캠퍼스 내까지 진입할 수 있습니다.
# • 원주역(흥업방면, 정류장 번호 68585)에서 30번, 34-1번 버스를 탑승하면 교내까지 이동할 수 있습니다.
# ----------------------------------------
# [5]
# 연세대학교 미래캠퍼스 2024 전화번호부 (부서별 연락처)
# 전화번호는 지역번호 033-760이후의 내선번호 4자리로 표시됩니다.
# • 교무부: 033-760-2158, 033-760-2589, 033-760-2714
# ----------------------------------------
# [6]
# ...
